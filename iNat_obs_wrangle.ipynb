# %% [markdown]
# ## Data Wrangling - iNaturalist National Park Observations
# ### This notebook imports and cleans data from inaturalist and merges it with national park visitation data

# %% [markdown]
# ### Import packages

# %%
import pandas as pd
from collections import defaultdict
from datetime import datetime
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Load the data

# %%
#Mammal observations from iNaturalist search "National Park" 
observations = pd.read_csv('Data/observations-141356.csv', parse_dates = [2])

# %% [markdown]
# ### Inspect data and select columns

# %%
#drop unneccessary columns and rows with place_country_names that are obviously not United States
observation = observations.drop(['id', 'observed_on_string', 'time_observed_at', 'time_zone', 'quality_grade','description', 'place_town_name','species_guess','taxon_id' ], axis= 1)
observation = observation.drop(observation[observation['place_country_name'] == 'Argentina'].index)

# %%
observation.head(2)
# Out:
#   observed_on                                        place_guess   latitude  \
# 0  2008-08-08  Yellowstone National Park, Park County, US-WY, US  44.811585
# 1  2009-05-14  Everglades National Park, Monroe County, US-FL...  25.153938
#
#     longitude place_county_name place_state_name place_country_name  \
# 0 -110.481333              Park          Wyoming      United States
# 1  -80.851790            Monroe          Florida      United States
#
#       scientific_name          common_name iconic_taxon_name
# 0         Bison bison       American Bison          Mammalia
# 1  Trichechus manatus  West Indian Manatee          Mammalia

# %% [markdown]
# The national park name needs to be extracted from the place_guess string. I need to be able to join the animal observations to the national park visitation data

# %%
#Create a dataframe that has a column with the original place_guess string and a column with national park name extracted from place_guess
#Get a dataframe that is a single column containing a list of the place_guess name. Drop duplicates.
place_guess = observations.filter(['place_guess', 'place_state_name'], axis = 1)
place_guess1 = place_guess.drop_duplicates(ignore_index = True)

#Use the separating commas to separate the place_guess string using its commas. the first part is the national park name
#Join the df with the park name in its own column to the place_guess column 
place_guess3 = pd.DataFrame(place_guess1.place_guess.str.split(',', expand= True))
place_guess5 = place_guess1.join(place_guess3)
place_guess5.rename(columns= {0:'c0', 1 : 'c1', 2:'c2', 3: 'c3', 4:'c4', 5: 'c5', 6:'c6'}, inplace= True)

# %%
place_guess5.head()
# Out:
#                                          place_guess place_state_name  \
# 0  Yellowstone National Park, Park County, US-WY, US          Wyoming
# 1  Everglades National Park, Monroe County, US-FL...          Florida
# 2         Kings Canyon/Sequoia National Park, NV, US       California
# 3         Antietam Battlefield National Park, MD, US         Maryland
# 4                      Yellowstone National Park, US          Wyoming
#
#                                    c0              c1      c2    c3    c4  \
# 0           Yellowstone National Park     Park County   US-WY    US  None
# 1            Everglades National Park   Monroe County   US-FL    US  None
# 2  Kings Canyon/Sequoia National Park              NV      US  None  None
# 3  Antietam Battlefield National Park              MD      US  None  None
# 4           Yellowstone National Park              US    None  None  None
#
#      c5    c6
# 0  None  None
# 1  None  None
# 2  None  None
# 3  None  None
# 4  None  None

# %%
# use .loc method to create a new column. dataframe_name.loc[condition, new_column_name] = new_column_value
place_guess5.loc[place_guess5['c0'].str.contains('National Park'), 'park'] = place_guess5['c0']
place_guess5.head()
# Out:
#                                          place_guess place_state_name  \
# 0  Yellowstone National Park, Park County, US-WY, US          Wyoming
# 1  Everglades National Park, Monroe County, US-FL...          Florida
# 2         Kings Canyon/Sequoia National Park, NV, US       California
# 3         Antietam Battlefield National Park, MD, US         Maryland
# 4                      Yellowstone National Park, US          Wyoming
#
#                                    c0              c1      c2    c3    c4  \
# 0           Yellowstone National Park     Park County   US-WY    US  None
# 1            Everglades National Park   Monroe County   US-FL    US  None
# 2  Kings Canyon/Sequoia National Park              NV      US  None  None
# 3  Antietam Battlefield National Park              MD      US  None  None
# 4           Yellowstone National Park              US    None  None  None
#
#      c5    c6                                park
# 0  None  None           Yellowstone National Park
# 1  None  None            Everglades National Park
# 2  None  None  Kings Canyon/Sequoia National Park
# 3  None  None  Antietam Battlefield National Park
# 4  None  None           Yellowstone National Park

# %%
#check for missing values in the park column
place_guess5.info()#park=431 non-null
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 737 entries, 0 to 736
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   place_guess       737 non-null    object
#  1   place_state_name  734 non-null    object
#  2   c0                737 non-null    object
#  3   c1                737 non-null    object
#  4   c2                736 non-null    object
#  5   c3                698 non-null    object
#  6   c4                105 non-null    object
#  7   c5                23 non-null     object
#  8   c6                1 non-null      object
#  9   park              431 non-null    object
# dtypes: object(10)
# memory usage: 57.7+ KB

# %%
#see if National Park part of the name got separated into 'c1' column bc of comma separation
place_guess5['c1'].fillna('None', inplace = True)
place_guess5.loc[place_guess5['c1'].str.contains('National Park'), 'park'] = place_guess5['c1']#park column=566 non-null

# %%
#see if National Park part of the name got separated into 'c2' column bc of comma separation
place_guess5['c2'].fillna('None', inplace = True)
place_guess5.loc[place_guess5['c2'].str.contains('National Park'), 'park'] = place_guess5['c2']#park column = 570 non-null

# %%
#see if National Park part of the name got separated into 'c3' column bc of comma separation
place_guess5['c3'].fillna('None', inplace = True)
place_guess5.loc[place_guess5['c3'].str.contains('National Park'), 'park'] = place_guess5['c3']#park column info = 570 non-null

# %%
#see if National Park part of the name got separated into 'c4' column bc of comma separation
place_guess5['c4'].fillna('None', inplace = True)
place_guess5.loc[place_guess5['c4'].str.contains('National Park'), 'park']= place_guess5['c4']#park column = 570 non-null, stop
place_guess5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 737 entries, 0 to 736
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   place_guess       737 non-null    object
#  1   place_state_name  734 non-null    object
#  2   c0                737 non-null    object
#  3   c1                737 non-null    object
#  4   c2                737 non-null    object
#  5   c3                737 non-null    object
#  6   c4                737 non-null    object
#  7   c5                23 non-null     object
#  8   c6                1 non-null      object
#  9   park              570 non-null    object
# dtypes: object(10)
# memory usage: 57.7+ KB

# %%
#570 rows have a national park name in the 'park' column. scan through the place_guess column for rows that don't have 'National Park' in place guess
#looks like most of these aren't national parks 
print(place_guess5.loc[place_guess5['park'].isnull()].place_guess.unique())
# Out:
# ['Temescal Gateway Park, Santa Monica Mountains National Recreation Area, Los Angeles County, US-CA, US'
#  'Honaunau National Historical Park, Honaunau, Hawaii, US'
#  'Marsh-Billings-Rockefeller National Historical Park, Windsor County, US-VT, US'
#  'Malibu Creek, Malibu Creek State Park, Santa Monica Mountains National Recreation Area, Los Angeles County, US-CA, US'
#  'Pepper Park, National City, California, US'
#  'Chaco Culture National Historical Park, Farmington, New Mexico, US'
#  'Montgomery County, Chesapeake and Ohio Canal National Historical Park, US-MD, US'
#  'National Zoological Park, Washington D.C., DC, US'
#  'National Mall and Memorial Parks, US-DC, District of Columbia County, US'
#  'Jean Lafitte National Historical Park and Preserve, Lafitte, LA, US'
#  'Redwood National and State Parks, Six Rivers Ntl Forest, CA, US'
#  'San Pedro Valley County Park, San Mateo County, Golden Gate National Recreation Area, US-CA, US'
#  'Crescent Lake, Olympic National park, Washington, US'
#  'Cumberland Gap National Historical Park, Ewing, VA, US'
#  'Cumberland Gap National Historical Park, Hulen, KY, US'
#  'Sitka National Historical Park, Sitka County, US-AK, US'
#  'National Zoological Park, Washington, DC, US'
#  'Sitka National Historical Park, Sitka, AK, US'
#  'Colonial National Historical Park, Williamsburg, VA, US'
#  'San Juan Island National Historical Park, San Juan County, US-WA, US'
#  'National Mall, National Mall and Memorial Parks, US-DC, District of Columbia County, US'
#  'Jefferson County, Jean Lafitte National Historical Park and Preserve, US-LA, US'
#  'Tomales Bay State Park, Point Reyes National Seashore, Marin County, US-CA, US'
#  'Tumacacori National Historical Park, Santa Cruz County, US-AZ, US'
#  'Smithsonian National Zoological Park, Washington, D.C., US'
#  'Chaco Culture National Historical Park, Farmington, NM, US'
#  'Saratoga National Historical Park, Saratoga County, US-NY, US'
#  'Angel Island State Park, Marin County, Golden Gate National Recreation Area, US-CA, US'
#  'National Mall and Memorial Parks, District of Columbia County, US-DC, US'
#  'Klondike Gold Rush National Historical Park, Skagway County, US-AK, US'
#  'Redwood National and State Parks, Trinidad, CA, US'
#  'Cumberland Gap National Historical Park, Middlesboro, KY, US'
#  "Pu'uhonua o Honaunau National Historic Park, Honaunau, HI, US"
#  'Mount Tamalpais State Park, Mount Tamalpais, Marin County, Golden Gate National Recreation Area, US-CA, US'
#  'Point Mugu, Point Mugu State Park, Santa Monica Mountains National Recreation Area, Ventura County, US-CA, US'
#  'Manassas National Battle Park, Manassas, VA, US'
#  'Manassas National Battlefield Park, Prince William County, US-VA, US'
#  'Kings Mountain National Military Park, Blacksburg, SC, US'
#  'Washington Monument, National Mall and Memorial Parks, District of Columbia County, US-DC, US'
#  'Don Edwards San Francisco Bay National Wildlife Refuge, Menlo Park, CA, US'
#  'Boston National Historical Park, Boston, MA, US'
#  'Marsh-Billings-Rockefeller National Historical Park, Woodstock, VT, US'
#  'Tumacacori National Historical Park, Tumacacori, AZ, US'
#  'National Mall, National Mall and Memorial Parks, District of Columbia County, US-DC, US'
#  'Arapaho National Forest, Winter Park, CO, US'
#  'Smithsonian National Zoological Park, Washington, DC, US'
#  'El Toyon Park, National City, CA, US'
#  'Colonial National Historical Park, Yorktown, VA, US'
#  'Topanga, Topanga State Park, Santa Monica Mountains National Recreation Area, Los Angeles County, US-CA, US'
#  'Wasatch-Cache National Forest, Park City, UT, US'
#  'Minute Man National Historical Park, Lincoln, MA, US'
#  'Pepper Park, National City, CA, US'
#  'Minute Man National Historical Park, Concord, MA, US'
#  'Richmond National Battlefield Park, Hanover County, US-VA, US'
#  'Redwood National and State Parks, Orick, CA, US'
#  'Franklin Canyon Park, Santa Monica Mountains National Recreation Area, Los Angeles County, US-CA, US'
#  'Saratoga National Historical Park, Stillwater, NY, US'
#  'Chesapeake and Ohio Canal National Historic Park, Washington, DC, US'
#  'Guilford Courthouse National Military Park, Greensboro, NC, US'
#  'Kaibab National Forest, Parks, AZ, US'
#  'Santa Monica Mountains National Recreation Area, Newbury Park, CA, US'
#  'Targhee National Forest, Island Park, ID, US'
#  'Samuel P. Taylor State Park, Marin County, Golden Gate National Recreation Area, US-CA, US'
#  'San Francisco Maritime National Historical Park, San Francisco, CA, US'
#  'Okanogan-Wenatchee National Forest, Okanogan Natl Park, WA, US'
#  'Ross Lake National Recreation Area, National Forest/Park, WA, US'
#  'Pike National Forest, Woodland Park, CO, US'
#  'Klondike Gold Rush National Historical Park, Skagway, AK, US'
#  'Gettysburg National Military Park, Cumberland, PA, US'
#  'Gettysburg National Military Park, Adams County, US-PA, US'
#  'Lewis and Clark National Historical Park, Pacific County, US-WA, US'
#  'San Francisco Maritime National Historical Park, Golden Gate Natl. Rec. Area - SF, San Francisco County, US-CA, US'
#  'Kennesaw Mountain National Battlefield Park, Cobb County, US-GA, US'
#  'San Juan Island National Historical Park, Friday Harbor, WA, US'
#  'SLAC National Accelerator Laboratory, Menlo Park, CA, US'
#  'Shiloh National Military Park, Adamsville, TN, US'
#  'Shiloh National Military Park, Shiloh, TN, US'
#  'Jean Lafitte National Historical Park and Preserve, Barataria, LA, US'
#  'Redwood National and State Parks, Hoopa, CA, US'
#  'Manassas National Battlefield Park, Manassas, VA, US'
#  'Chesapeake and Ohio Canal National Historical Park, US-MD, US'
#  'Manassas National Battlefield Park, Gainesville, VA, US'
#  'Los Padres National Forest, Frazier Park, CA, US'
#  'Richmond National Battlefield Park, Henrico, VA, US'
#  'Kennesaw Mountain National Battlefield Park, Marietta, GA, US'
#  'Mussel Rock Park, San Mateo County, Golden Gate National Recreation Area, US-CA, US'
#  'Henrico County, Richmond National Battlefield Park, US-VA, US'
#  'Browns Park National Wildlife Refuge, Moffat County, US-CO, US'
#  'Gettysburg National Military Park, Gettysburg, PA, US'
#  'First State National Historical Park, New Castle County, US-DE, US'
#  'Chaco Culture National Historical Park, Bloomfield, NM, US'
#  'Kings Mountain National Military Park, Cherokee County, US-SC, US'
#  'Santa Monica Mountains National Recreation Area, Oak Park, CA, US'
#  'Will Rogers State Historic Park, Santa Monica Mountains National Recreation Area, Los Angeles County, US-CA, US'
#  'Redwood National and State Parks, Blue Lake, CA, US'
#  'Morristown National Historical Park, Bernardsville, NJ, US'
#  'Independence National Historic Park, Philadelphia, PA, US'
#  'Minute Man National Historical Park, Hanscom Afb, MA, US'
#  'Cibola National Forest, Sandia Park, NM, US'
#  'Lyndon B. Johnson National Historical Park, Blanco County, US-TX, US'
#  'Chickamauga and Chattanooga National Military Park, Fort Oglethorpe, GA, US'
#  'Independence National Historical Park, Philadelphia County, US-PA, US'
#  'Muir Woods National Monument, Mount Tamalpais State Park, Mount Tamalpais, Marin County, US-CA, US'
#  'Minute Man National Historical Park, Middlesex County, US-MA, US'
#  'Chesapeake & Ohio Canal National Heritage Park, Bethesda, MD, US'
#  'Fredericksburg & Spotsylvania National Military Park, Fredericksburg, VA, US'
#  'Chesapeake & Ohio Canal National Heritage Park, Potomac, MD, US'
#  'Chesapeake & Ohio Canal National Heritage Park, Brunswick, MD, US'
#  'Ocmulgee National Monument Park, Macon, GA, US'
#  'Chesapeake & Ohio Canal National Heritage Park, Glen Echo, MD, US'
#  'Redwood National and State Parks, Klamath, CA, US'
#  'Lewis and Clark National Historical Park, Pacific County, US-WA, Lewis and Clark National Historic Trail, US'
#  'Chesapeake & Ohio Canal National Heritage Park, Poolesville, MD, US'
#  'Allegany County, Chesapeake and Ohio Canal National Historical Park, US-MD, US'
#  'Canaveral National Seashore Park, Mims, FL, US'
#  'Washington County, Chesapeake and Ohio Canal National Historical Park, US-MD, US'
#  'Chesapeake & Ohio Canal National Historical Park, Washington, DC, US'
#  'Pisgah National Forest, Elk Park, NC, US'
#  'Valley Forge National Historical Park, King Of Prussia, PA, US'
#  "Pu'uhonua O Hōnaunau National Historical Park, Honaunau, HI, US"
#  'Ocmulgee Mounds National Historical Park, Macon, GA, US'
#  'Independence National Historical Park, Philadelphia, PA, US'
#  'Wichita Mountains National Wildlife Refuge, Mountain Park, OK, US'
#  'Colorado National Monument, Glade Park, CO, US'
#  'Harpers Ferry National Historical Park, Harpers Ferry, WV, US'
#  'Minute Man National Historical Park, Lexington, MA, US'
#  'Hopewell Culture National Historical Park, Chillicothe, OH, US'
#  'Umpqua National Forest, Idleyld Park, OR, US'
#  'Caribou-Targhee National Forest, Henrys Lake State Park, Island Park, ID, US'
#  'Chickamauga and Chattanooga National Military Park, Walker County, US-GA, US'
#  'Morristown National Historical Park, Morristown, NJ, US'
#  'Pea Ridge National Military Park, Garfield, AR, US'
#  'Pike and San Isabel National Forests, Woodland Park, CO, US'
#  'Chickamauga & Chattanooga National Military Park, Chattanooga, TN, US'
#  'Klondike Gold Rush National Historic Park, AK, US'
#  'Arapaho National Forest, Estes Park, CO, US'
#  'New Orleans Jazz National Historical Park, New Orleans, LA, US'
#  'Lyndon B Johnson National Historical Park, Johnson City, TX, US'
#  'Manassas National Battlefield Park Virginia, Manassas, VA, US'
#  'Klondike Gold Rush National Historical Park, AK, US'
#  'Lewis and Clark National Historical Park, Astoria, OR, US'
#  'Caribou-Targhee National Forest, Island Park, ID, US'
#  'Richmond National Battlefield Park, Mechanicsville, VA, US'
#  'Arapaho & Roosevelt National Forests Pawnee National Grassland, Estes Park, CO, US'
#  'Harpers Ferry National Historical Park, Loudoun County, US-VA, US'
#  'Coconino National Forest, Munds Park, AZ, US'
#  'Colonial National Historic Park, Yorktown, VA, US'
#  'Fredericksburg and Spotsylvania National Military Park, Stafford County, US-VA, US'
#  'Valley Forge National Historical Park, Norristown, PA, US'
#  'Lyndon B Johnson National Historical Park, Stonewall, TX, US'
#  'Lewis and Clark National Historical Park, Ilwaco, WA, US'
#  'Colonial National Historic Park, Williamsburg, VA, US'
#  'Keweenaw National Historical Park, Hancock, MI, US'
#  'Pecos National Historical Park, Pecos, NM, US'
#  'Tumacácori National Historical Park, Carmen, AZ, US'
#  'Keweenaw National Historical Park, Houghton County, US-MI, US'
#  'Jean Lafitte National Historic Park and Preserve, Barataria, LA, US'
#  'Cumberland Gap National Historic Park, Middlesboro, KY, US'
#  'Kennesaw Mountain National Battlefield Park, Kennesaw, GA, US'
#  'Cumberland Gap National Historic Park, Keokee, VA, US'
#  'Arapaho & Roosevelt National Forests Pawnee National Grassland, Winter Park, CO, US'
#  'Lowell National Historical Park, Lowell, MA, US'
#  'Rosie the Riveter WWII Home Front National Historical Park, Richmond, CA, US'
#  'Public, Montgomery County, Chesapeake and Ohio Canal National Historical Park, US-MD, US'
#  'Appomattox Court House National Historical Park, Appomattox, VA, US'
#  'Palo Alto Battlefield National Historical Park, Brownsville, TX, US'
#  'Lyndon B. Johnson National Historical Park, Johnson City, TX, US']

# %%
#scan for issues should be about 63
print(place_guess5.park.unique(),len(place_guess5.park.unique()))
# Out:
# ['Yellowstone National Park' 'Everglades National Park'
#  'Kings Canyon/Sequoia National Park' 'Antietam Battlefield National Park'
#  'Death Valley National Park' 'Grand Teton National Park'
#  ' Yellowstone National Park' ' Mount Rainier National Park'
#  'Redwood National Park' 'Channel Islands National Park'
#  'Denali National Park' ' Grand Canyon National Park'
#  'Mount Rainier National Park' 'Yosemite National Park'
#  ' Rocky Mountain National Park' nan
#  ' Sequoia and Kings Canyon National Parks'
#  'Cuyahoga Valley National Park' ' Olympic National Park'
#  ' North Cascades National Park' 'Glacier National Park'
#  ' Glacier National Park' ' Theodore Roosevelt National Park'
#  'Glacier Bay National Park' 'Shenandoah National Park'
#  'Badlands National Park' 'Big Bend National Park'
#  'Theodore Roosevelt National Park South Unit'
#  ' Grand Teton National Park' ' Big Bend National Park'
#  ' Yosemite National Park' 'Bryce Canyon National Park'
#  'Kenai Fjords National Park' 'Joshua Tree National Park'
#  'enali National Park' 'Wind Cave National Park' ' Katmai National Park'
#  'Katmai National Park' 'Sequoia National Park' 'Saguaro National Park'
#  'Pinnacles National Park' ' Sequoia National Park'
#  'Grand Canyon National Park' ' Great Smoky Mountains National Park'
#  'Acadia National Park' 'Denali National Park and Preserve'
#  'North Cascades National Park Service Complex' 'Zion National Park'
#  ' North Cascades National Park Service Complex'
#  'Petrified Forest National Park' ' Denali National Park'
#  'Glacier Bay National Park and Preserve' 'Arches National Park'
#  ' Saguaro National Park' 'Canyonlands National Park'
#  'Hawaii Volcanoes National Park' 'Rocky Mountain National Park'
#  ' Crater Lake National Park' 'Olympic National Park'
#  'Wrangell-St. Elias National Park' ' Pinnacles National Park'
#  ' Shenandoah National Park' 'Mesa Verde National Park'
#  'Gates of the Arctic National Park' ' Kenai Fjords National Park'
#  '65–79 Zion National Park' 'Great Smoky Mountains National Park'
#  ' Death Valley National Park'
#  'Gates of the Arctic National Park and Preserve' 'Biscayne National Park'
#  ' Petrified Forest National Park' 'Piscataway National Park'
#  'Theodore Roosevelt National Park - North Unit'
#  ' Lassen Volcanic National Park' ' Hot Springs National Park'
#  'Kings Canyon National Park' ' Acadia National Park'
#  'Great Basin National Park' 'Isle Royale National Park'
#  'Black Canyon of the Gunnison National Park'
#  'Wolf Trap Farm Park National Park' 'Mammoth Cave National Park'
#  'Crater Lake National Park' 'Virgin Islands National Park'
#  ' Great Basin National Park' 'Katmai National Park and Preserve'
#  'Congaree National Park' 'Guadalupe Mountains National Park'
#  'Capitol Reef National Park' ' Everglades National Park'
#  ' Redwood National Park' 'Lassen Volcanic National Park'
#  'Carlsbad Caverns National Park' ' Jr. National Park'
#  'Great Sand Dunes National Park and Preserve'
#  'North Cascades National Park' '281 Zion National Park'
#  'Grand Canyon National Park South Rim'
#  'Saguaro National Park East - Rincon Mountain District'
#  'Glacier National Park Glacier'
#  'Wolf Trap National Park for the Performing Arts'
#  'Hawai‘i Volcanoes National Park' '205 Zion National Park'
#  'Theodore Roosevelt National Park' 'Hot Springs National Park'
#  'Everglades National Park Lakes' '95 Zion National Park'
#  'Sequoia and Kings Canyon National Parks' 'Voyageurs National Park'
#  '101–111 Great Basin National Park'
#  'Gates of the Arctic National Park & Preserve'
#  'Sequoia & Kings Canyon National Park' 'Lake Clark National Park'
#  'Wrangell-St Elias National Park & Preserve'
#  'Saguaro National Park - Rincon Mountain District (East)'
#  'Indiana Dunes National Park' 'Tierra del Fuego National Park'
#  'Haleakalā National Park' 'Kenai Fiords National Park'
#  'Great Sand Dunes National Park & Preserve Colorado'
#  ' Channel Islands National Park' 'Kobuk Valley National Park'
#  'Grand Teton National Park Pond' 'Lake Clark National Park and Preserve'
#  ' National Park' 'Saguaro National Park West'
#  'Katmai National Park & Preserve'
#  'Saguaro National Park - Tucson Mountain District (West)'
#  'Glacier Bay National Park & Preserve' ' Great Sand Dunes National Park'
#  'Great Sand Dunes National Park' 'Denali National Park & Preserve'
#  'Rocky Mountain National Park Administration Building'
#  'US National Park Rd' 'White Sands National Park'
#  'Jaime Benitez National Park' 'Steptoe Butte National Park'] 137

# %%
#df name changed bc of some deleted code
place_guess6 = place_guess5

# %%
place_guess6.head()
# Out:
#                                          place_guess place_state_name  \
# 0  Yellowstone National Park, Park County, US-WY, US          Wyoming
# 1  Everglades National Park, Monroe County, US-FL...          Florida
# 2         Kings Canyon/Sequoia National Park, NV, US       California
# 3         Antietam Battlefield National Park, MD, US         Maryland
# 4                      Yellowstone National Park, US          Wyoming
#
#                                    c0              c1      c2    c3    c4  \
# 0           Yellowstone National Park     Park County   US-WY    US  None
# 1            Everglades National Park   Monroe County   US-FL    US  None
# 2  Kings Canyon/Sequoia National Park              NV      US  None  None
# 3  Antietam Battlefield National Park              MD      US  None  None
# 4           Yellowstone National Park              US    None  None  None
#
#      c5    c6                                park
# 0  None  None           Yellowstone National Park
# 1  None  None            Everglades National Park
# 2  None  None  Kings Canyon/Sequoia National Park
# 3  None  None  Antietam Battlefield National Park
# 4  None  None           Yellowstone National Park

# %%
place_guess6['park'].fillna('None', inplace = True)

# %%
#remove leading numbers or extra words
place_guess6['park'] = place_guess6.park.str.strip('-1234567890')
place_guess6['park'] = place_guess6.park.str.strip('–11179')
place_guess6['park'] = place_guess6.park.str.rstrip('& and Preserve')
place_guess6['park'] = place_guess6.park.str.rstrip('Service Complex')
place_guess6['park'] = place_guess6.park.str.rstrip('Pond')

# %%
#remove leading or trailing whitespaces
place_guess6['park'] = place_guess6.park.str.strip()

# %%
#create a function to rename typos 
def re_name(df, column, prob_name, new_name):
    """filter rows of column for the problem name and replace all matches with consistent corrected name
    Args:
        df: dataframe name
        column(str): name of column
        prob_name(str): part of the string that needs to be replaced
        new_name(str): corrected string
    Returns: df with correction"""
    df.loc[df[column].str.contains(prob_name), column] = new_name

# %%
re_name(df=place_guess6, column = 'park', prob_name = 'Theodore Roosevelt National Park', new_name = 'Theodore Roosevelt National Park')
re_name(df=place_guess6, column = 'park', prob_name = 'Grand Canyon National', new_name = 'Grand Canyon National')
re_name(df=place_guess6, column = 'park', prob_name = 'North Cascades National Park', new_name = 'North Cascades National Park')
re_name(df=place_guess6, column = 'park', prob_name = 'Saguaro National Park', new_name = 'Saguaro National Park')
re_name(df=place_guess6, column = 'park', prob_name = 'Rocky Mountain National Park', new_name = 'Rocky Mountain National Park')
re_name(df=place_guess6, column = 'park', prob_name = 'Everglades National Park', new_name = 'Everglades National Park')
re_name(df=place_guess6, column = 'park', prob_name = 'Glacier National Park', new_name = 'Glacier National Park')
re_name(df=place_guess6, column = 'park', prob_name = 'Sequoia National Park', new_name = 'Sequoia and Kings Canyon National Park')
re_name(df=place_guess6, column = 'park', prob_name = 'Kings Canyon National Park', new_name = 'Sequoia and Kings Canyon National Park')
re_name(df=place_guess6, column = 'park', prob_name = 'Great Sand Dunes National Park', new_name = 'Great Sand Dunes National Park')
re_name(df=place_guess6, column = 'park', prob_name = 'Jr. National Park', new_name = 'Yellowstone National Park')
re_name(df=place_guess6, column = 'park', prob_name = 'Haleakalā', new_name = 'Haleakala National Park')
re_name(df=place_guess6, column = 'park', prob_name = 'Hawai‘i', new_name = 'Hawaii Volcanoes National Park')
re_name(df=place_guess6, column = 'park', prob_name = 'Wrangell', new_name = 'Wrangell-St. Elias National Park')
re_name(df=place_guess6, column = 'park', prob_name = 'Kenai', new_name = 'Kenai Fjords National Park')
re_name(df=place_guess6, column = 'park', prob_name = 'Gunnison', new_name = 'Black Canyon of the Gunnison National Park')
re_name(df=place_guess6, column = 'park', prob_name = 'enali', new_name = 'Denali National Park')

# %%
#some of the non-national park names in the park column
problem_list = ['National Park','Jaime Benitez National Park','Wolf Trap National Park for the Performing Art','Wolf Trap Farm Park National Park',
                'Jr. National Park', 'N', 'US National Park R', 'Tierra del Fuego National Park', 'Piscataway National Park', 'Steptoe Butte National Park','Butte National Park', 'Antietam Battlefield National Park']

# %%
#what are the 'N' values? can a National Park name be easily identified?
place_guess6[place_guess6['park'] == 'N']
# Out:
#                                            place_guess place_state_name  \
# 22   Temescal Gateway Park, Santa Monica Mountains ...       California
# 27   Honaunau National Historical Park, Honaunau, H...           Hawaii
# 45   Marsh-Billings-Rockefeller National Historical...          Vermont
# 50   Malibu Creek, Malibu Creek State Park, Santa M...       California
# 53          Pepper Park, National City, California, US       California
# ..                                                 ...              ...
# 727  Rosie the Riveter WWII Home Front National His...       California
# 729  Public, Montgomery County, Chesapeake and Ohio...         Maryland
# 732  Appomattox Court House National Historical Par...         Virginia
# 734  Palo Alto Battlefield National Historical Park...            Texas
# 735  Lyndon B. Johnson National Historical Park, Jo...            Texas
#
#                                                     c0  \
# 22                               Temescal Gateway Park
# 27                   Honaunau National Historical Park
# 45   Marsh-Billings-Rockefeller National Historical...
# 50                                        Malibu Creek
# 53                                         Pepper Park
# ..                                                 ...
# 727  Rosie the Riveter WWII Home Front National His...
# 729                                             Public
# 732    Appomattox Court House National Historical Park
# 734     Palo Alto Battlefield National Historical Park
# 735         Lyndon B. Johnson National Historical Park
#
#                                                    c1  \
# 22    Santa Monica Mountains National Recreation Area
# 27                                           Honaunau
# 45                                     Windsor County
# 50                            Malibu Creek State Park
# 53                                      National City
# ..                                                ...
# 727                                          Richmond
# 729                                 Montgomery County
# 732                                        Appomattox
# 734                                       Brownsville
# 735                                      Johnson City
#
#                                                     c2                   c3  \
# 22                                  Los Angeles County                US-CA
# 27                                              Hawaii                   US
# 45                                               US-VT                   US
# 50     Santa Monica Mountains National Recreation Area   Los Angeles County
# 53                                          California                   US
# ..                                                 ...                  ...
# 727                                                 CA                   US
# 729   Chesapeake and Ohio Canal National Historical...                US-MD
# 732                                                 VA                   US
# 734                                                 TX                   US
# 735                                                 TX                   US
#
#          c4    c5    c6 park
# 22       US  None  None    N
# 27     None  None  None    N
# 45     None  None  None    N
# 50    US-CA    US  None    N
# 53     None  None  None    N
# ..      ...   ...   ...  ...
# 727    None  None  None    N
# 729      US  None  None    N
# 732    None  None  None    N
# 734    None  None  None    N
# 735    None  None  None    N
#
# [167 rows x 10 columns]

# %%
#drop the rows that with 'park' column values in the problem list
place_guess7 = place_guess6
for thing in problem_list:
    place_guess7 = place_guess7.drop(place_guess7[place_guess7['park']== thing].index)

# %%
#about 63 parks so not all represented in the data
print(len(place_guess7.park.unique()))
# Out:
# 58

# %%
#drop the extra columns
place_guess8 = place_guess7.drop(['c0', 'c1', 'c2', 'c3', 'c4', 'c5','c6'], axis = 1)
place_guess7.shape, place_guess8.shape
# Out:
# ((561, 10), (561, 3))

# %%
#found this place_guess with 100 null observations in the merge below
#append place guess Redwood National and State Parks, Trinidad, CA, US    'Redwood' 'CA' 'Redwood National Park'
R_W = {'place_guess': 'Redwood National and State Parks, Trinidad, CA, US', 'place_state_name': 'California' , 'park': 'Redwood National Park'}
place_guess8 = place_guess8.append(R_W, ignore_index = True)
# Out:
# C:\Users\jpsan\AppData\Local\Temp\ipykernel_7972\2952220423.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   place_guess8 = place_guess8.append(R_W, ignore_index = True)

# %%
place_guess8.tail()
# Out:
#                                            place_guess place_state_name  \
# 557  Death Valley National Park, Nye County, US-NV, US           Nevada
# 558         El Capitan, Yosemite National Park, CA, US       California
# 559                 Death Valley National Park, CA, US       California
# 560      Glacier Point, Yosemite National Park, CA, US       California
# 561  Redwood National and State Parks, Trinidad, CA...       California
#
#                            park
# 557  Death Valley National Park
# 558      Yosemite National Park
# 559  Death Valley National Park
# 560      Yosemite National Park
# 561       Redwood National Park

# %%
#need to add a state abbreviation column
state_abbr = pd.read_csv('Data/states_name_abbr.csv')
state_abbr.head()
# Out:
#   state        name
# 0    AK      Alaska
# 1    AL     Alabama
# 2    AR    Arkansas
# 3    AZ     Arizona
# 4    CA  California

# %%
#merge state_abbr on to place_guess this adds state abbreviation column
df = place_guess8.merge(state_abbr,left_on = 'place_state_name', right_on= 'name')
df.head()
# Out:
#                                          place_guess place_state_name  \
# 0  Yellowstone National Park, Park County, US-WY, US          Wyoming
# 1                      Yellowstone National Park, US          Wyoming
# 2               Yellowstone National Park, US-WY, US          Wyoming
# 3                  Grand Teton National Park, WY, US          Wyoming
# 4                  Yellowstone National Park, WY, US          Wyoming
#
#                         park state     name
# 0  Yellowstone National Park    WY  Wyoming
# 1  Yellowstone National Park    WY  Wyoming
# 2  Yellowstone National Park    WY  Wyoming
# 3  Grand Teton National Park    WY  Wyoming
# 4  Yellowstone National Park    WY  Wyoming

# %%
# merging more park identifier columns preparing to merge dataframes
parks = pd.read_csv('Data/parks_unique.csv', index_col = 0)
parks.head()
# Out:
#     ParkName State         Park                    park
# 0    Acadia     ME    Acadia NP    Acadia National Park
# 1    Arches     UT    Arches NP    Arches National Park
# 2  Badlands     SD  Badlands NP  Badlands National Park
# 3  Big Bend     TX  Big Bend NP  Big Bend National Park
# 4  Biscayne     FL  Biscayne NP  Biscayne National Park

# %%
df2= pd.merge(df, parks, on = 'park', how = 'left')
df2.head()
# Out:
#                                          place_guess place_state_name  \
# 0  Yellowstone National Park, Park County, US-WY, US          Wyoming
# 1                      Yellowstone National Park, US          Wyoming
# 2               Yellowstone National Park, US-WY, US          Wyoming
# 3                  Grand Teton National Park, WY, US          Wyoming
# 4                  Yellowstone National Park, WY, US          Wyoming
#
#                         park state     name      ParkName State  \
# 0  Yellowstone National Park    WY  Wyoming  Yellowstone     WY
# 1  Yellowstone National Park    WY  Wyoming  Yellowstone     WY
# 2  Yellowstone National Park    WY  Wyoming  Yellowstone     WY
# 3  Grand Teton National Park    WY  Wyoming  Grand Teton     WY
# 4  Yellowstone National Park    WY  Wyoming  Yellowstone     WY
#
#              Park
# 0  Yellowstone NP
# 1  Yellowstone NP
# 2  Yellowstone NP
# 3  Grand Teton NP
# 4  Yellowstone NP

# %%
#finally merging all of the cleaned park identifying columns back to the the original animal observation df from inaturalist
df_merge = pd.merge(observation, df2, on=['place_guess', 'place_state_name'], how = 'left')
df_merge.head()
# Out:
#   observed_on                                        place_guess   latitude  \
# 0  2008-08-08  Yellowstone National Park, Park County, US-WY, US  44.811585
# 1  2009-05-14  Everglades National Park, Monroe County, US-FL...  25.153938
# 2  2009-06-08         Kings Canyon/Sequoia National Park, NV, US  36.489655
# 3  2009-06-08         Kings Canyon/Sequoia National Park, NV, US  36.520012
# 4  2010-04-11         Kings Canyon/Sequoia National Park, NV, US  36.524426
#
#     longitude place_county_name place_state_name place_country_name  \
# 0 -110.481333              Park          Wyoming      United States
# 1  -80.851790            Monroe          Florida      United States
# 2 -118.779289            Tulare       California      United States
# 3 -118.795425            Tulare       California      United States
# 4 -118.751480            Tulare       California      United States
#
#                     scientific_name                 common_name  \
# 0                       Bison bison              American Bison
# 1                Trichechus manatus         West Indian Manatee
# 2  Odocoileus hemionus californicus        California Mule Deer
# 3          Otospermophilus beecheyi  California Ground Squirrel
# 4          Otospermophilus beecheyi  California Ground Squirrel
#
#   iconic_taxon_name                                    park state        name  \
# 0          Mammalia               Yellowstone National Park    WY     Wyoming
# 1          Mammalia                Everglades National Park    FL     Florida
# 2          Mammalia  Sequoia and Kings Canyon National Park    CA  California
# 3          Mammalia  Sequoia and Kings Canyon National Park    CA  California
# 4          Mammalia  Sequoia and Kings Canyon National Park    CA  California
#
#                     ParkName State                         Park
# 0               Yellowstone     WY               Yellowstone NP
# 1                Everglades     FL                Everglades NP
# 2  Sequoia and Kings Canyon     CA  Sequoia and Kings Canyon NP
# 3  Sequoia and Kings Canyon     CA  Sequoia and Kings Canyon NP
# 4  Sequoia and Kings Canyon     CA  Sequoia and Kings Canyon NP

# %%
#I think I need to get rid of the problem list observations to get rid of the 1000 entry discrepency
df_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16583 entries, 0 to 16582
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   observed_on         16583 non-null  datetime64[ns]
#  1   place_guess         16583 non-null  object
#  2   latitude            16582 non-null  float64
#  3   longitude           16582 non-null  float64
#  4   place_county_name   16552 non-null  object
#  5   place_state_name    16579 non-null  object
#  6   place_country_name  16567 non-null  object
#  7   scientific_name     16583 non-null  object
#  8   common_name         16564 non-null  object
#  9   iconic_taxon_name   16583 non-null  object
#  10  park                15874 non-null  object
#  11  state               15874 non-null  object
#  12  name                15874 non-null  object
#  13  ParkName            15284 non-null  object
#  14  State               15284 non-null  object
#  15  Park                15284 non-null  object
# dtypes: datetime64[ns](1), float64(2), object(13)
# memory usage: 2.2+ MB

# %%
nul_df2 = df_merge[df_merge.park.isnull()]
nul_df2.place_guess.value_counts()
# Out:
# Targhee National Forest, Island Park, ID, US                                                       32
# Marsh-Billings-Rockefeller National Historical Park, Woodstock, VT, US                             24
# Santa Monica Mountains National Recreation Area, Newbury Park, CA, US                              24
# San Pedro Valley County Park, San Mateo County, Golden Gate National Recreation Area, US-CA, US    20
# Chesapeake and Ohio Canal National Historic Park, Washington, DC, US                               20
#                                                                                                    ..
# Ocmulgee National Monument Park, Macon, GA, US                                                      1
# Virgin Islands National Park, Coral Bay, VI, US                                                     1
# Channel Islands National Park, Channel Islands, Santa Barbara County, US-CA, US                     1
# Fredericksburg & Spotsylvania National Military Park, Fredericksburg, VA, US                        1
# Steptoe Butte National Park, Colfax, WA, US                                                         1
# Name: place_guess, Length: 181, dtype: int64

# %%
#don't need any of the observations with unknown NP 
df_merge2 = df_merge.drop(df_merge[df_merge.park.isnull()].index, axis = 0)

# %%
#drop some of the unnecessary columns
df_merge2 = df_merge2.drop(['place_county_name', 'place_country_name', 'name', 'State'], axis = 1)
df_merge2.head()
# Out:
#   observed_on                                        place_guess   latitude  \
# 0  2008-08-08  Yellowstone National Park, Park County, US-WY, US  44.811585
# 1  2009-05-14  Everglades National Park, Monroe County, US-FL...  25.153938
# 2  2009-06-08         Kings Canyon/Sequoia National Park, NV, US  36.489655
# 3  2009-06-08         Kings Canyon/Sequoia National Park, NV, US  36.520012
# 4  2010-04-11         Kings Canyon/Sequoia National Park, NV, US  36.524426
#
#     longitude place_state_name                   scientific_name  \
# 0 -110.481333          Wyoming                       Bison bison
# 1  -80.851790          Florida                Trichechus manatus
# 2 -118.779289       California  Odocoileus hemionus californicus
# 3 -118.795425       California          Otospermophilus beecheyi
# 4 -118.751480       California          Otospermophilus beecheyi
#
#                   common_name iconic_taxon_name  \
# 0              American Bison          Mammalia
# 1         West Indian Manatee          Mammalia
# 2        California Mule Deer          Mammalia
# 3  California Ground Squirrel          Mammalia
# 4  California Ground Squirrel          Mammalia
#
#                                      park state                   ParkName  \
# 0               Yellowstone National Park    WY               Yellowstone
# 1                Everglades National Park    FL                Everglades
# 2  Sequoia and Kings Canyon National Park    CA  Sequoia and Kings Canyon
# 3  Sequoia and Kings Canyon National Park    CA  Sequoia and Kings Canyon
# 4  Sequoia and Kings Canyon National Park    CA  Sequoia and Kings Canyon
#
#                           Park
# 0               Yellowstone NP
# 1                Everglades NP
# 2  Sequoia and Kings Canyon NP
# 3  Sequoia and Kings Canyon NP
# 4  Sequoia and Kings Canyon NP

# %%
#Save this as csv for EDA and join to park visitation data
#df_merge2.to_csv('Data/observations_park.csv')
