# %%
pip install tabula-py
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import tabula
import pandas as pd

# %%
#declare the path of your file
file_path = "Data/fy2021.pdf" 
#Convert your file
df = tabula.read_pdf(file_path, pages= "126-138")
# Out:
# Got stderr: Jan 23, 2021 12:57:57 PM org.apache.pdfbox.pdmodel.graphics.color.PDICCBased ensureDisplayProfile
# WARNING: ICC profile is Perceptual, ignoring, treating as Display class
# Jan 23, 2021 12:57:58 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO: Your current java version is: 1.8.0_171
# Jan 23, 2021 12:57:58 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO: To get higher rendering speed on old java 1.8 or 9 versions,
# Jan 23, 2021 12:57:58 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO:   update to the latest 1.8 or 9 version (>= 1.8.0_191 or >= 9.0.4),
# Jan 23, 2021 12:57:58 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO:   or
# Jan 23, 2021 12:57:58 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO:   use the option -Dsun.java2d.cmm=sun.java2d.cmm.kcms.KcmsServiceProvider
# Jan 23, 2021 12:57:58 PM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# ...

# %%
df[0].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  27 non-null     object
#  1   FY 2019     26 non-null     object
#  2   Unnamed: 1  21 non-null     object
#  3   Unnamed: 2  5 non-null      float64
#  4   Unnamed: 3  26 non-null     object
#  5   Unnamed: 4  26 non-null     object
#  6   FY 2021     26 non-null     object
#  7   Unnamed: 5  26 non-null     object
#  8   Unnamed: 6  0 non-null      float64
#  9   Unnamed: 7  26 non-null     object
# dtypes: float64(2), object(8)
# memory usage: 2.3+ KB

# %%
df[0] #interested in column 'Unamed 3' Fy 2019 Actual
# Out:
#                                            Unnamed: 0    FY 2019  \
# 0   OPERATION OF THE NATIONAL PARK SYSTEM ORGANIZA...  Park Base
# 1                                                 NaN       FTE1
# 2                                     PARK BASE UNITS        NaN
# 3                                              Parks8        NaN
# 4                      Abraham Lincoln Birthplace NHS         12
# 5                                           Acadia NP         67
# 6                                           Adams NHP         20
# 7                           African Burial Grounds NM          7
# 8                                Agate Fossil Beds NM          7
# 9                      Allegheny Portage Railroad NHS         14
# 10                                        Amistad NRA         32
# 11                                  Andersonville NHS         12
# 12                                 Andrew Johnson NHS         10
# ...

# %%
print(df[0]['Unnamed: 0'].iloc[4:])
# Out:
# 4                      Abraham Lincoln Birthplace NHS
# 5                                           Acadia NP
# 6                                           Adams NHP
# 7                           African Burial Grounds NM
# 8                                Agate Fossil Beds NM
# 9                      Allegheny Portage Railroad NHS
# 10                                        Amistad NRA
# 11                                  Andersonville NHS
# 12                                 Andrew Johnson NHS
# 13                                        Antietam NB
# 14                                 Apostle Islands NL
# 15                                    Appalachian NST
# 16                         Appomattox Court House NHP
# 17                                          Arches NP
# 18                                 Arkansas Post NMem
# 19                               Assateague Island NS
# 20                                     Aztec Ruins NM
# ...

# %%
budget_2019= df[0].iloc[4:, 4]
budget_2019.index = df[0]['Unnamed: 0'].iloc[4:]
budget_2019.columns = ['FY_2019']
budget_2019.head()
# Out:
# Unnamed: 0
# Abraham Lincoln Birthplace NHS    1,367
# Acadia NP                         8,338
# Adams NHP                         2,535
# African Burial Grounds NM         1,993
# Agate Fossil Beds NM                934
# Name: Unnamed: 3, dtype: object

# %%
df[1]
# Out:
#                                            Unnamed: 0    FY 2019  \
# 0   OPERATION OF THE NATIONAL PARK SYSTEM ORGANIZA...  Park Base
# 1                                                 NaN       FTE1
# 2                                   Big Thicket NPres         22
# 3                                  Bighorn Canyon NRA         32
# 4                          Birmingham Civil Rights NM          0
# 5                                         Biscayne NP         27
# 6                     Black Canyon of the Gunnison NP         16
# 7                         Blackstone River Valley NHP          4
# 8                                  Blue Ridge Parkway        144
# 9                                       Bluestone NSR          0
# 10                             Booker T Washington NM          8
# 11                        Boston African American NHS          8
# 12                          Boston Harbor Islands NRA         18
# ...
